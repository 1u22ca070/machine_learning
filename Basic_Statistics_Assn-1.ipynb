# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\gorak\Downloads\Basic stats - 1\Basic stats - 1\sales_data_with_discounts.csv")
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
df.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495427     47847.912852
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    int64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    int64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 45.8+ KB

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'SKU', 'City', 'Volume', 'BU', 'Brand', 'Model',
#        'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Date                 0
# Day                  0
# SKU                  0
# City                 0
# Volume               0
# BU                   0
# Brand                0
# Model                0
# Avg Price            0
# Total Sales Value    0
# Discount Rate (%)    0
# Discount Amount      0
# Net Sales Value      0
# dtype: int64

# %%
df.nunique()
# Out:
# Date                  15
# Day                    7
# SKU                   30
# City                   1
# Volume                22
# BU                     3
# Brand                  9
# Model                 30
# Avg Price             25
# Total Sales Value    135
# Discount Rate (%)    450
# Discount Amount      450
# Net Sales Value      450
# dtype: int64

# %%
import matplotlib.pyplot as plt
df.hist(bins=5,edgecolor='black',figsize=(13,10))
plt.suptitle('Histogram for each numeric column')
plt.show()

# %%
from scipy.stats import skew
print('skew of total Sales Value: %f'%df['Total Sales Value'].skew())
print('skew of Avg Price: %f'%df['Avg Price'].skew())
print('skew of Discount Rate: %f'%df['Discount Rate (%)'].skew())
print('skew of Discount Amount: %f'%df['Discount Amount'].skew())
print('skew of Net Sales Value: %f'%df['Net Sales Value'].skew())
# Out:
# skew of total Sales Value: 1.534729
# skew of Avg Price: 1.908873
# skew of Discount Rate: -1.062294
# skew of Discount Amount: 1.913038
# skew of Net Sales Value: 1.540822

# %%
import seaborn as sns
df.boxplot(figsize=(13,3))
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import pandas as pd
data=df
fig=plt.figure()
ax=fig.add_axes([0,0,0.5,1.0])
x=list(data.iloc[0:,[1,3,5,6,7]])
y=list(data.iloc[0:,[1,3,5,6,7]])
ax.bar(x,y)
plt.show()

# %%
x=df.iloc[:,:7]
x
# Out:
#            Date       Day  SKU City  Volume         BU  Brand
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM
# ..          ...       ...  ...  ...     ...        ...    ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera
#
# [450 rows x 7 columns]

# %%
x=df.iloc[:,:7]
x
# Out:
#            Date       Day  SKU City  Volume         BU  Brand
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM
# ..          ...       ...  ...  ...     ...        ...    ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera
#
# [450 rows x 7 columns]

# %%
import statistics
mean=df['Net Sales Value'].mean()
df['z_score']=(df['Net Sales Value']-mean)/46358.656624
df['z_score']
# Out:
# 0      2.801638
# 1      1.269613
# 2      1.543957
# 3      1.763847
# 4     -0.227342
#          ...
# 445   -0.609783
# 446   -0.378079
# 447   -0.601252
# 448   -0.554881
# 449   -0.600571
# Name: z_score, Length: 450, dtype: float64

# %%
import statistics
mean=df['Avg Price'].mean()
df['z_score']=(df['Avg Price']-mean)/18079.904840
df['z_score']
# Out:
# 0      0.091072
# 1     -0.019548
# 2      0.312312
# 3      0.533552
# 4     -0.130168
#          ...
# 445   -0.506277
# 446   -0.434374
# 447   -0.489684
# 448   -0.473091
# 449   -0.406719
# Name: z_score, Length: 450, dtype: float64

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'SKU', 'City', 'Volume', 'BU', 'Brand', 'Model',
#        'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value', 'z_score'],
#       dtype='object')

# %%
import statistics
mean=df['Total Sales Value'].mean()
df['z_score']=(df['Total Sales Value']-mean)/50535.074173
df['z_score']
# Out:
# 0      2.922469
# 1      1.329516
# 2      1.561038
# 3      1.717365
# 4     -0.188242
#          ...
# 445   -0.617647
# 446   -0.360400
# 447   -0.605774
# 448   -0.556303
# 449   -0.607753
# Name: z_score, Length: 450, dtype: float64

# %%
import statistics
mean=df['Discount Rate (%)'].mean()
df['z_score']=(df['Discount Rate (%)']-mean)/18079.904840
df['z_score']
# Out:
# 0     -0.000194
# 1     -0.000199
# 2     -0.000315
# 3     -0.000455
# 4      0.000157
#          ...
# 445    0.000018
# 446    0.000105
# 447    0.000211
# 448    0.000091
# 449    0.000010
# Name: z_score, Length: 450, dtype: float64

# %%
import statistics
mean=df['Discount Amount'].mean()
df['z_score']=(df['Discount Amount']-mean)/4509.902963
df['z_score']
# Out:
# 0      3.948422
# 1      1.846958
# 2      1.621190
# 3      1.112568
# 4      0.227598
#          ...
# 445   -0.652815
# 446   -0.152022
# 447   -0.607464
# 448   -0.529789
# 449   -0.636636
# Name: z_score, Length: 450, dtype: float64

# %%
x=pd.get_dummies(df,columns=['Brand'])
x
# Out:
#            Date       Day  SKU City  Volume         BU       Model  Avg Price  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles       RU-10      12100
# 1    01-04-2021  Thursday  M02    C      10    Mobiles   RU-9 Plus      10100
# 2    01-04-2021  Thursday  M03    C       7    Mobiles       YM-99      16100
# 3    01-04-2021  Thursday  M04    C       6    Mobiles  YM-99 Plus      20100
# 4    01-04-2021  Thursday  M05    C       3    Mobiles      YM-98        8100
# ..          ...       ...  ...  ...     ...        ...         ...        ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle   M-Casuals       1300
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   W-Western       2600
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle    W-Lounge       1600
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle   M-Formals       1900
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle     M-Shoes       3100
#
# ...

# %%
x=pd.get_dummies(df,columns=['Date'])
x
# Out:
#           Day  SKU City  Volume         BU  Brand       Model  Avg Price  \
# 0    Thursday  M01    C      15    Mobiles  RealU       RU-10      12100
# 1    Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus      10100
# 2    Thursday  M03    C       7    Mobiles   YouM       YM-99      16100
# 3    Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus      20100
# 4    Thursday  M05    C       3    Mobiles   YouM      YM-98        8100
# ..        ...  ...  ...     ...        ...    ...         ...        ...
# 445  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals       1300
# 446  Thursday  L07    C       6  Lifestyle   Viva   W-Western       2600
# 447  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge       1600
# 448  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals       1900
# 449  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes       3100
#
#      Total Sales Value  Discount Rate (%)  ...  Date_06-04-2021  \
# ...

# %%
x=pd.get_dummies(df,columns=['Day'])
x
# Out:
#            Date  SKU City  Volume         BU  Brand       Model  Avg Price  \
# 0    01-04-2021  M01    C      15    Mobiles  RealU       RU-10      12100
# 1    01-04-2021  M02    C      10    Mobiles  RealU   RU-9 Plus      10100
# 2    01-04-2021  M03    C       7    Mobiles   YouM       YM-99      16100
# 3    01-04-2021  M04    C       6    Mobiles   YouM  YM-99 Plus      20100
# 4    01-04-2021  M05    C       3    Mobiles   YouM      YM-98        8100
# ..          ...  ...  ...     ...        ...    ...         ...        ...
# 445  15-04-2021  L06    C       2  Lifestyle  Jeera   M-Casuals       1300
# 446  15-04-2021  L07    C       6  Lifestyle   Viva   W-Western       2600
# 447  15-04-2021  L08    C       2  Lifestyle   Viva    W-Lounge       1600
# 448  15-04-2021  L09    C       3  Lifestyle  Jeera   M-Formals       1900
# 449  15-04-2021  L10    C       1  Lifestyle  Jeera     M-Shoes       3100
#
# ...

# %%
x=pd.get_dummies(df,columns=['SKU'])
x
# Out:
#            Date       Day City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  ...  SKU_M01  SKU_M02  \
# ...

# %%
x=pd.get_dummies(df,columns=['City'])
x
# Out:
#            Date       Day  SKU  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
x=pd.get_dummies(df,columns=['BU'])
x
# Out:
#            Date       Day  SKU City  Volume  Brand       Model  Avg Price  \
# 0    01-04-2021  Thursday  M01    C      15  RealU       RU-10      12100
# 1    01-04-2021  Thursday  M02    C      10  RealU   RU-9 Plus      10100
# 2    01-04-2021  Thursday  M03    C       7   YouM       YM-99      16100
# 3    01-04-2021  Thursday  M04    C       6   YouM  YM-99 Plus      20100
# 4    01-04-2021  Thursday  M05    C       3   YouM      YM-98        8100
# ..          ...       ...  ...  ...     ...    ...         ...        ...
# 445  15-04-2021  Thursday  L06    C       2  Jeera   M-Casuals       1300
# 446  15-04-2021  Thursday  L07    C       6   Viva   W-Western       2600
# 447  15-04-2021  Thursday  L08    C       2   Viva    W-Lounge       1600
# 448  15-04-2021  Thursday  L09    C       3  Jeera   M-Formals       1900
# 449  15-04-2021  Thursday  L10    C       1  Jeera     M-Shoes       3100
#
#      Total Sales Value  Discount Rate (%)  Discount Amount  Net Sales Value  \
# ...

# %%
x=pd.get_dummies(df,columns=['Model'])
x
# Out:
#            Date       Day  SKU City  Volume         BU  Brand  Avg Price  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU      12100
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU      10100
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM      16100
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM      20100
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM       8100
# ..          ...       ...  ...  ...     ...        ...    ...        ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera       1300
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva       2600
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva       1600
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera       1900
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera       3100
#
#      Total Sales Value  Discount Rate (%)  ...  Model_Vedic Cream  \
# ...
